# %% [markdown]
# Day 24
#
# Word embeddings (Word2Vec, GloVe)
#
# # Greet Learning
#     https://www.mygreatlearning.com/blog/word-embedding/
#
# #
#     https://atrijpaul.hashnode.dev/exquisite-exposition-of-word-embeddings
