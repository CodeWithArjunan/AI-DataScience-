# %%
x = '---------python---------'
print(x.strip('-'))
# Out:
# python

# %%
print(x.lstrip('-'))
print(x.rstrip('-'))
print(x.strip('p'))  
# # apple
#   ↑
# p is in the MIDDLE
# 👉 strip() never touches the middle
# Out:
# python---------
# ---------python
# ---------python---------

# %%
x = "pythonp"

print(x.lstrip('p'))
# Out:
# ythonp

# %%
x = '---------python---------'

print(x.replace('p', ''))
# Out:
# ---------ython---------

# %%
x='pythonp'
print(x.strip('p'))
# Out:
# ython

# %%
s = "banana"
sorted_s = list("".join(sorted(s)))
# print(sorted_s) # Output: aaabnn
t="banana"
tshort = list("".join(sorted(t)))
print(sorted_s)
print(tshort)
# Out:
# ['a', 'a', 'a', 'b', 'n', 'n']
# ['a', 'a', 'a', 'b', 'n', 'n']
